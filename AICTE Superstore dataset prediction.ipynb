# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importing the datasets using pandas 
df= pd.read_csv("C:\\Users\\91895\\Desktop\\Yassh project folder\\Myproject.csv", encoding ='windows-1254')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# Cleaning the data 
df1= df.drop(columns=['Row ID','Order ID','Customer ID','Postal Code','Product ID','Customer Name','Product Name','Country'])
df1.head(5)
# Out:
#    Order Date   Ship Date       Ship Mode    Segment             City  \
# 0   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 1   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 2   6/12/2016   6/16/2016    Second Class  Corporate      Los Angeles
# 3  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
# 4  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
#
#         State Region         Category Sub-Category     Sales  Quantity  \
# 0    Kentucky  South        Furniture    Bookcases  261.9600         2
# 1    Kentucky  South        Furniture       Chairs  731.9400         3
# 2  California   West  Office Supplies       Labels   14.6200         2
# 3     Florida  South        Furniture       Tables  957.5775         5
# 4     Florida  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# ...

# %%
#checking the last five element of the dataset
df1.tail()
# Out:
#      Order Date  Ship Date       Ship Mode   Segment         City       State  \
# 9989  1/21/2014  1/23/2014    Second Class  Consumer        Miami     Florida
# 9990  2/26/2017   3/3/2017  Standard Class  Consumer   Costa Mesa  California
# 9991  2/26/2017   3/3/2017  Standard Class  Consumer   Costa Mesa  California
# 9992  2/26/2017   3/3/2017  Standard Class  Consumer   Costa Mesa  California
# 9993   5/4/2017   5/9/2017    Second Class  Consumer  Westminster  California
#
#      Region         Category Sub-Category    Sales  Quantity  Discount  \
# 9989  South        Furniture  Furnishings   25.248         3       0.2
# 9990   West        Furniture  Furnishings   91.960         2       0.0
# 9991   West       Technology       Phones  258.576         2       0.2
# 9992   West  Office Supplies        Paper   29.600         4       0.0
# 9993   West  Office Supplies   Appliances  243.160         2       0.0
#
#        Profit
# 9989   4.1028
# 9990  15.6332
# 9991  19.3932
# ...

# %%
#checking the top 5 values of the dataset
df1.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Segment             City  \
# 0   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 1   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 2   6/12/2016   6/16/2016    Second Class  Corporate      Los Angeles
# 3  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
# 4  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
#
#         State Region         Category Sub-Category     Sales  Quantity  \
# 0    Kentucky  South        Furniture    Bookcases  261.9600         2
# 1    Kentucky  South        Furniture       Chairs  731.9400         3
# 2  California   West  Office Supplies       Labels   14.6200         2
# 3     Florida  South        Furniture       Tables  957.5775         5
# 4     Florida  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# ...

# %%
df1.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Here , we can see that the total sales is 22638.480000 and the profit was made 8399.976000

# %%
# Discount and profit relation 
df1.plot(x='Discount',y='Profit',style='o')
plt.xlable('Discount')
plt.ylable('Profit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14880\3718538210.py in <module>
#       1 # Discount and profit relation
#       2 df1.plot(x='Discount',y='Profit',style='o')
# ----> 3 plt.xlable('Discount')
#       4 plt.ylable('Profit')
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# We can see, when discount is 0.4 or more than that , we are selling in loss

# %% [markdown]
# # Category was Sales and Profit

# %%
df1.plot(x='Category', y='Sales', style='o')
plt.xlable('Category')
plt.ylable('Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14880\295244229.py in <module>
#       1 df1.plot(x='Category', y='Sales', style='o')
# ----> 2 plt.xlable('Category')
#       3 plt.ylable('Sales')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# # Category vs Profit Graph

# %%
df1.plot(x='Category',y='Profit',style='o')
plt.xlable('Category')
plt.ylable('Profit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14880\4200804627.py in <module>
#       1 df1.plot(x='Category',y='Profit',style='o')
# ----> 2 plt.xlable('Category')
#       3 plt.ylable('Profit')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
df1.groupby("Category")["Sales"].sum().plot.pie(autopct="%0.1f%%")
df['Category'].value_counts().describe
# Out:
# <bound method NDFrame.describe of Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64>

# %% [raw]
# Here, we can see that maximum  sales in the tecnology.
# We can see that minimum sales in the Office Supplies.

# %% [markdown]
# # Sub-Category Analysis

# %%
df1.groupby("Sub-Category")["Sales"].sum().plot.pie(autopct="%0.1f%%")
df['Sub-Category'].value_counts().describe
# Out:
# <bound method NDFrame.describe of Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64>

# %% [raw]
# Here, we can see that Phones, Chairs and storage hold a good market .So ,we can saw the Techology  and Office supplies are cover more market part but  the funiture good is not appropiate in the market.

# %% [markdown]
# # Segment with Sales

# %%
df1.groupby("Segment")["Sales"].sum().plot.pie(autopct="%0.1f%%")
df['Segment'].value_counts().describe
# Out:
# <bound method NDFrame.describe of Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64>

# %% [raw]
# As,B2C bussiness,company is doing good . But in the home and office supply of the product is very less .This may be indecation of less awareness of thebrand of the market.

# %% [markdown]
# # Sales and Profit is the based upon location

# %%
df1.plot(x='State', y='Profit', style='o')
plt.xlable('State')
plt.ylable('Profit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14880\4131779742.py in <module>
#       1 df1.plot(x='State', y='Profit', style='o')
# ----> 2 plt.xlable('State')
#       3 plt.ylable('Profit')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# # City Vs Profit

# %%
df1.plot(x='City', y='Profit', style='o')
plt.xlable('City')
plt.ylable('Profit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14880\557701209.py in <module>
#       1 df1.plot(x='City', y='Profit', style='o')
# ----> 2 plt.xlable('City')
#       3 plt.ylable('Profit')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
df['State'].value_counts().describe
# Out:
# <bound method NDFrame.describe of California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# ...

# %%
df['City'].value_counts().describe
# Out:
# <bound method NDFrame.describe of New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64>

# %%
df1.groupby("Region")["Sales"].sum().plot.pie(autopct="%0.1f%%")
df['Region'].value_counts().describe
# Out:
# <bound method NDFrame.describe of West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64>

# %% [raw]
# South region is haveing least sale.some of the cities that shows weak market aquisition are Missouri City ,Rouchester Hill, Palatine, Manhattan,and states are Whymoing,West Virgina,North Dakota.

# %% [markdown]
# # Conclusion

# %% [markdown]
# As a Business Manager , I would be decreasing the discount given to the coustomers,work on the quality satandards of my technical products and furnitures . I would also like to run advertisement and other campaign so that people living in cities like Manhattan also get to know about it.
